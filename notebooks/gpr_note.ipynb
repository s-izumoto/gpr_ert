# %%
import numpy as np
npz = np.load("inversion_MI_field000.npz")
inv_rho = npz["inv_rho_cells"]

print("min,max =", inv_rho.min(), inv_rho.max())
# Out:
# min,max = 11.928216323308565 499.66371107750643
